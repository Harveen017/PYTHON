# %% [markdown]
# <a href="https://colab.research.google.com/github/Harveen017/Python/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-e87909df-eeaf-4548-a4a2-7aa0dffec7e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e87909df-eeaf-4548-a4a2-7aa0dffec7e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris.csv

# %%
import pandas as pd
iris=pd.read_csv('iris.csv')
iris.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
iris[iris['sepalwidth']>4]
# Out:
#     sepallength  sepalwidth  petallength  petalwidth        class
# 15          5.7         4.4          1.5         0.4  Iris-setosa
# 32          5.2         4.1          1.5         0.1  Iris-setosa
# 33          5.5         4.2          1.4         0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x='sepallength',y='petallength',data=iris,hue='class')
plt.show()

# %% [markdown]
# #LINEAR REGRESSION

# %%
y=iris[['sepallength']]
x=iris[['sepalwidth']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
x_train.head()
# Out:
#      sepalwidth
# 56          3.3
# 24          3.4
# 111         2.7
# 105         3.0
# 122         2.8

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
y_pred[0:5]
# Out:
# array([[6.04508038],
#        [5.90690181],
#        [6.18325895],
#        [5.72266372],
#        [5.95296134]])

# %% [markdown]
# #ERROR IN PREDICTION

# %%
from  sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.755143752528919

# %% [markdown]
# #MODEL 2

# %%
y=iris[['sepallength']]
x=iris[['sepalwidth','petallength','petalwidth']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
lr2=LinearRegression()
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)
mean_squared_error(y_test,y_pred)
# Out:
# 0.09728860649167985

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-868b423b-f74d-49a1-9f01-e0e9aa29f996" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-868b423b-f74d-49a1-9f01-e0e9aa29f996">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid_19_india.csv to covid_19_india.csv

# %%
import pandas as pd
df=pd.read_csv('covid_19_india.csv')

# %% [markdown]
# #RENAMING  THE COLUMNS

# %%
df=df[['Date','State/UnionTerritory','Cured','Deaths','Confirmed']]
df.columns=['date','state','cured','deaths','confirmed']
df.head()
# Out:
#          date   state  cured  deaths  confirmed
# 0  2020-01-30  Kerala      0       0          1
# 1  2020-01-31  Kerala      0       0          1
# 2  2020-02-01  Kerala      0       0          2
# 3  2020-02-02  Kerala      0       0          3
# 4  2020-02-03  Kerala      0       0          3

# %%
today=df[df.date=='2020-07-17']
today
# Out:
#             date                                     state   cured  deaths  \
# 4179  2020-07-17               Andaman and Nicobar Islands     133       0
# 4180  2020-07-17                            Andhra Pradesh   19393     492
# 4181  2020-07-17                         Arunachal Pradesh     153       3
# 4182  2020-07-17                                     Assam   12888      48
# 4183  2020-07-17                                     Bihar   14018     197
# 4184  2020-07-17                                Chandigarh     476      11
# 4185  2020-07-17                              Chhattisgarh    3451      21
# 4186  2020-07-17  Dadra and Nagar Haveli and Daman and Diu     371       2
# 4187  2020-07-17                                     Delhi   97693    3545
# 4188  2020-07-17                                       Goa    1817      19
# 4189  2020-07-17                                   Gujarat   32103    2089
# ...

# %%
max_confirmed_cases=today.sort_values(by='confirmed',ascending='False')
print(max_confirmed_cases)
# Out:
#             date                                     state   cured  deaths  \
# 4179  2020-07-17               Andaman and Nicobar Islands     133       0
# 4207  2020-07-17                                    Sikkim      88       0
# 4201  2020-07-17                                   Mizoram     160       0
# 4200  2020-07-17                                 Meghalaya      66       2
# 4214  2020-07-17          Cases being reassigned to states       0       0
# 4181  2020-07-17                         Arunachal Pradesh     153       3
# 4186  2020-07-17  Dadra and Nagar Haveli and Daman and Diu     371       2
# 4184  2020-07-17                                Chandigarh     476      11
# 4202  2020-07-17                                  Nagaland     391       0
# 4196  2020-07-17                                    Ladakh     970       1
# 4191  2020-07-17                          Himachal Pradesh     984      11
# ...

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(20,20)})
sns.barplot(x='state',y='confirmed',data=df,hue='state')
plt.show()
